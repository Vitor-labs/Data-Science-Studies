# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

plt.style.use('dark_background')

# %%
data = pd.read_excel("./../Datasets/Dados.xlsx", sheet_name='Query result')
#data.head()
data.head()
# Out:
#         Data  Vendas
# 0 2022-12-06     870
# 1 2022-12-07     868
# 2 2022-12-08    1189
# 3 2022-12-09     742
# 4 2022-12-10     317

# %%
data['Data'] = [i.weekday() for i in data['Data']]

model = LinearRegression().fit(data, data['Vendas'])
pred = model.predict(X)
# Out:
# c:\Users\Computador\anaconda3\envs\frexco\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 4
#       1 #data['Data'] = [i.weekday() for i in data['Data']]
#       3 model = LinearRegression().fit(data, data['Vendas'])
# ----> 4 pred = model.predict(X)
#
# File c:\Users\Computador\anaconda3\envs\frexco\lib\site-packages\sklearn\linear_model\_base.py:355, in LinearModel.predict(self, X)
#     341 def predict(self, X):
#     342     """
#     343     Predict using the linear model.
#     344
#    (...)
#     353         Returns predicted values.
#     354     """
# --> 355     return self._decision_function(X)
#
# ...

# %%
plt.figure(figsize=(16,8))
plt.scatter(X, Y, c='black')
plt.xlabel('Money spent on TV ads ($)')
plt.ylabel('Sales made on these ads (k$)')
data.plot()
plt.plot(X, c='blue', linewidth=2)
